# %% [markdown]
# <a href="https://colab.research.google.com/github/ersharadpal/python/blob/main/Copy_of_Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
User_input="Sharad"
print(len(User_input))
print(User_input[-1])
print(User_input[1])
# Out:
# 6
# d
# h

# %%
User_input="Sharad"
print(User_input[-1::-1])
# Out:
# darahS

# %%
User_input="Sharad"
print(len(User_input))
#print(User_input[0])
#print(User_input[-1])
print(User_input[0:3])
# Out:
# 6
# Sha

# %%
User_list="sharad"
print(User_list.lower())
# Out:
# sharad

# %%
User_list="sharad"
print(User_list.lower())
print(User_list.upper())
print(User_list.title())
# Out:
# sharad
# SHARAD
# Sharad

# %%
text=" data analyst"
text.strip()
# Out:
# 'data analyst'

# %%
text="New-york"
text.replace("-"," ")
# Out:
# 'New york'

# %%
email="abc@gmail.com"
email.find("d")
#email.count("a")
# Out:
# -1

# %%
email="abc@gmail.com"
#email.isalpha()
#email.isdigit()
#email.alnum()
#email.startswith("a")
#email.endswith(".com")
#email.count("a")
# Out:
# True

# %%
text="data analyst"
text.count("a")
# Out:
# 4

# %%
email="student@gmail.com"
email.split("student@")
# Out:
# ['', 'gmail.com']

# %%
var="India"
length=len(var)
for i in range(length):
#for i in var:
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
