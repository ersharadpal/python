# %% [markdown]
# <a href="https://colab.research.google.com/github/ersharadpal/python/blob/main/Copy_of_For%20loop11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d=[]
for i in range (2:20:2)
  i=count+

Print("Number is even:",(i))
# Out:
#   File "/tmp/ipython-input-3190089729.py", line 2
#     for i in range (2:20:2)
#                      ^
# SyntaxError: invalid syntax

# %%
num=7
if num%2==0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
r=2

pi=3.14

area=pi*(r**2)
print(area)
# Out:
# 12.56

# %% [markdown]
# def add(a,b):
#   return a+b
#
#  def = defining a function
#  a,b = paramters(inputs)
#  return = output

# %%
def add(a,b):
  return a+b
c=add(3,10)
print (c)

# %%
def accio(a,b):
  return a+b  #function close
c=accio(3,10)
print (c)
# Out:
# 13

# %%
def greet():
  print("Hello batch 10")

  return

c=greet()

print(c)
# Out:
# Hello batch 10
# None

# %%
def greet(a,b): #parameters = placeholders
 d=a+b
 return d
c=greet(2,5) #Arguments

print(c)
# Out:
# 7

# %%
def greet2():
  print("Hello batch 10")

greet2()

# %%
def add(r,pi=3.14):
  return pi*(r**2)

d=add(4)

print(d)

# %%
def area(r,pi=22/7):
  e=input("enter any num:")
  return pi*(r**2)

g=input()
d=area(g,3.24)

print d

# %%
def greet():
 message = "Hello"
 print(message)

greet()
print(message)
# Out:
# Hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-330332166.py in <cell line: 0>()
#       4
#       5 greet()
# ----> 6 print(message)
#
# NameError: name 'message' is not defined

# %%
city="Noida"

def newcity():
  pub="Chandigarh"
  return city

city=newcity()

print(city)
# Out:
# Noida

# %%
count = 10

def increase():
  global count
  count=count+1
  return count

increase()
# Out:
# 11

# %%
# LAmda function

add=lambda a,b:a+b
print(add(3,4))
# Out:
# 7

# %%
powe=lambda a,b:a**b
print(powe(2,4))
# Out:
# 16

# %%
a=int(input())
b=int(input())
powe=lambda a,b:a**b
print(powe(a,b))
# Out:
# 2
# 3
# 8

# %%
def square(a):
  c=a**2
  return c
d= square(2)
print (d)
# Out:
# 4

# %%
def even (a):
  if a%2!=0:
