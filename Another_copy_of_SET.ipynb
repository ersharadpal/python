# %% [markdown]
# <a href="https://colab.research.google.com/github/ersharadpal/python/blob/main/Another_copy_of_SET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set
s3=set()
print(type(s3))
print(s3)
# Out:
# <class 'set'>
# set()

# %%
list1=[1,2,3,5,6,7,7]

s4=set(list1)

print(s4)
print(type(s4))

# Set is constructer and remove duplicate
# Out:
# {1, 2, 3, 5, 6, 7}
# <class 'set'>

# %%
s3.add(3)
s3.add(4)
print(s3)
# Out:
# {3, 4}

# %%
s4.update([10,12,999])
print(s4)
# Out:
# {1, 2, 3, 5, 6, 7, 999, 10, 12}

# %%
s4.update((10,12,99))
print(s4)
# Out:
# {1, 2, 3, 99, 5, 6, 7, 999, 10, 12}

# %%
xourse="acciojob"
se=set(xourse)
print(se)
# Out:
# {'j', 'i', 'b', 'a', 'c', 'o'}

# %%
tup1=("aman","akash","aman","Akash")
print(tup1)

se_tup=set(tup1)
print(se_tup)
# Out:
# ('aman', 'akash', 'aman', 'Akash')
# {'aman', 'akash', 'Akash'}

# %%
print("before",se_tup)
se_tup.remove("aman")
print("after",se_tup)
# Out:
# before {'aman', 'akash', 'Akash'}
# after {'akash', 'Akash'}

# %%
print("before",se_tup)

se_tup.discard("aman")

print("after",se_tup)
# Out:
# before {'akash', 'Akash'}
# after {'akash', 'Akash'}

# %%
set1={"aman","akash","aman","Akash"}

for i in set1:
  print(i)
# Out:
# aman
# akash
# Akash

# %%
friends=["aman","jeetu","ram","shyam","krishan"]
c=set(friends)
c.remove("ram")
print(c)
# Out:
# {'krishan', 'aman', 'jeetu', 'shyam'}

# %%
a=set()
a.update(["aman","ram"])
print(a)
a.remove("ram")
print(a)
# Out:
# {'aman', 'ram'}
# {'aman'}

# %%
#Union operator
a={1,2,3}
b={3,4,5}

print(a|b)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Union operator
a={1,2,3}
b={3,4,5}
final=a.union(b)
print(final)

#print(a|b)
# Out:
# {1, 2, 3, 4, 5}

# %%
#intersaction

set1={1,3,3,3,4,5}
set2={1,2,3,4,5}
set1.intersection(set2)


#print(set1&set2)
# Out:
# {1, 3, 4, 5}

# %%
set1={1,3,3,3,4,5}
set2={1,2,3,4,5}
set1.difference(set2)


#
# Out:
# {1, 3, 4, 5}

# %%
course1={"english","hindi"}
course2={"english","sanskrit"}

c=course1.union(course2) # combine and unique
print(c)
d=course1.intersection(course2)
print(d)
e=course1.difference(course2)
print(e)
f=course1.symmetric_difference(course2)
print(f)
# Out:
# {'sanskrit', 'hindi', 'english'}
# {'english'}
# {'hindi'}
# {'sanskrit', 'hindi'}

# %%
data=[10,20,20,30,40,40]
c=set(data)
print(c)
# Out:
# {40, 10, 20, 30}

# %%
s={1,2,3,3,2}
print(s)
# Out:
# {1, 2, 3}

# %%
a=set()
a.add(1)
a.add(2)
a.add(3)
print(a)
# Out:
# {1, 2, 3}

# %%
s={}
s.add(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1459303180.py in <cell line: 0>()
#       1 s={}
# ----> 2 s.add(10)
#
# AttributeError: 'dict' object has no attribute 'add'

# %%
a={2,4,6,8}
b={4,8,12}
a.union(b)
# Out:
# {2, 4, 6, 8, 12}

# %%
a={10,20,30,40}
a.discard(30)
print(a)
# Out:
# {40, 10, 20}

# %%
5 in {5,10,15,20}
# Out:
# True

# %%
sentence ='python is easy and python is powerful'
a=set(sentence.split())
print(a)
# Out:
# {'python', 'is', 'powerful', 'and', 'easy'}

# %%
person={
    "name":"aman",
    "marks":21,
    "is_male":True
}
print(person)

print(type(person))
# Out:
# {'name': 'aman', 'marks': 21, 'is_male': True}
# <class 'dict'>

# %%
batch10={
    "name":["aman","akash","aditi","rahul"],
    "assignment":[23,24,25,27],
    "Is_male":[True,True,False,True],
    "gender":["Male","Male","Female","Male"]
}

print(batch10)
print(batch10["name"][-1])
#batch10.keys()
#batch10.items()
#batch10.values()
# Out:
# {'name': ['aman', 'akash', 'aditi', 'rahul'], 'assignment': [23, 24, 25, 27], 'Is_male': [True, True, False, True], 'gender': ['Male', 'Male', 'Female', 'Male']}
# rahul
# dict_items([('name', ['aman', 'akash', 'aditi', 'rahul']), ('assignment', [23, 24, 25, 27]), ('Is_male', [True, True, False, True]), ('gender', ['Male', 'Male', 'Female', 'Male'])])

# %%
for key,value in batch10.items():
 print(key,value)
# Out:
# name ['aman', 'akash', 'aditi', 'rahul']
# assignment [23, 24, 25, 27]
# Is_male [True, True, False, True]
# gender ['Male', 'Male', 'Female', 'Male']

# %%
s= {10, 20, 30}
s.add(20)
print(len(s))
# Out:
# 3

# %%
s={100,200,300}
c= list(s)
print(type(c))
print(c)
# Out:
# <class 'list'>
# [200, 100, 300]

# %%
s= set('hello')
print(s)
# Out:
# {'o', 'e', 'l', 'h'}

# %%
text='programming'
s= set(text)
print(s)
# Out:
# {'i', 'n', 'o', 'p', 'm', 'g', 'r', 'a'}

# %%
class_A = {'Aman','Riya','Karan','Neha'}
class_B = {'Neha','Simran','Aman'}
c= class_A.union (class_B)
print(c)
# Out:
# {'Simran', 'Aman', 'Riya', 'Karan', 'Neha'}

# %%
a=[1,2,3]
3 in a
# Out:
# True

# %%
# x=0
for x in range (10):
 if x % 2 == 0 :
   print(x)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
nums=[10,15,20,25]
for x in nums:
  if x>=15 :
   print(x)
   x+1
# Out:
# 15
# 20
# 25

# %%
pd.read_csv("/content/sample_data/Student_CSV.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3020138998.py in <cell line: 0>()
# ----> 1 pd.read_csv("/content/sample_data/Student_CSV.csv")
#
# NameError: name 'pd' is not defined

# %%
df=pd.read_csv("/content/sample_data/Student_CSV.csv")

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/Student_CSV.csv")

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'City', 'Age', 'Score', 'JoinedDate', 'IsActive'], dtype='object')

# %%
df.head()
# Out:
#   StudentID       Name       City  Age  Score  JoinedDate  IsActive
# 0      S001  Student_1       Pune   26  58.55  2024-01-01      True
# 1      S002  Student_2    Kolkata   22  76.41  2024-01-02     False
# 2      S003  Student_3    Kolkata   18  92.66  2024-01-03     False
# 3      S004  Student_4  Bengaluru   22  58.34  2024-01-04     False
# 4      S005  Student_5      Delhi   29  81.87  2024-01-05      True

# %%
df.tail()
# Out:
#    StudentID         Name       City  Age  Score  JoinedDate  IsActive
# 95      S096   Student_96  Bengaluru   22  95.57  2024-04-05     False
# 96      S097   Student_97  Bengaluru   26  72.55  2024-04-06     False
# 97      S098   Student_98      Delhi   22  49.99  2024-04-07      True
# 98      S099   Student_99     Mumbai   29  67.41  2024-04-08      True
# 99      S100  Student_100  Hyderabad   23  79.15  2024-04-09     False

# %%
df.shape
# Out:
# (100, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   100 non-null    object
#  1   Name        100 non-null    object
#  2   City        100 non-null    object
#  3   Age         100 non-null    int64
#  4   Score       100 non-null    float64
#  5   JoinedDate  100 non-null    object
#  6   IsActive    100 non-null    bool
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 4.9+ KB

# %%
df.describe()
# Out:
#               Age       Score
# count  100.000000  100.000000
# mean    24.410000   69.760800
# std      3.654512   17.535534
# min     18.000000   40.240000
# 25%     21.750000   54.735000
# 50%     25.000000   71.050000
# 75%     28.000000   84.325000
# max     30.000000   99.930000

# %%
pd.series([1,2,3,4,5])
pd.series(["Delhi","Noida","Gurgaon"])
pd.series([23.6,24.6,89.6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1474263340.py in <cell line: 0>()
# ----> 1 pd.series([1,2,3,4,5])
#       2 pd.series(["Delhi","Noida","Gurgaon"])
#       3 pd.series([23.6,24.6,89.6])
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
I
# Out:
#   File "/tmp/ipython-input-2196311645.py", line 1
#     Import pandas
#            ^
# SyntaxError: invalid syntax
