# %% [markdown]
# <a href="https://colab.research.google.com/github/ersharadpal/python/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=["a","b","c","d"]
y=[20,30,40,70]
plt.plot(x,y)
plt.show()
# plt.plot(y)

# %%
x=["a","b","c","d"]
y=[20,30,40,70]
plt.plot(x,y, color="red")
plt.show()
# plt.plot(y)

# %%
import numpy as np
xdata = np.array([0,6])
ydata = np.array([0,250])
plt.plot(xdata,ydata, marker="o")
plt.show()

# %%
x=["2","8","2","10"]
y=[20,30,40,70]
plt.plot(x, color="red", marker="o")
plt.show()

# %%
xdata = np.array([1,8])
ydata = np.array([3,10])
plt.plot(xdata,ydata, marker="o")
plt.show()

# %%
xdata1 = np.arange(1,8)
ydata1 = np.arange(3,10)
plt.plot(xdata1,ydata1, marker="o")
plt.show()

# %%
xdata = np.array([1,8])
ydata = np.array([3,10])
plt.plot(xdata,ydata,"o")
plt.show()

# %%
#plt.plot(x,y,"o:b") #FMT = Format
plt.plot(x,y,"--")
plt.show()

# %%
plt.plot(x,y,"o:b",ms="10") #FMT = Format
# plt.plot(x,y,"--")
plt.show()

# %%
plt.figure(figsize=(2,6)) #(Width, Height)
plt.plot(x,y,"o:b",ms="10") #FMT = Format
# plt.plot(x,y,"--")
plt.show()

# %%
plt.plot(x,y,color="blue",marker="o",linestyle="dashed",linewidth=2,markersize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=[10,20,80,40,50]
y=[30,40,95,40,68]
k=[20,30,15,5,4]

z=["a","b","b","d","e"]
plt.plot(z,x,label="2025-sales")
plt.plot(z,y,label="2026-sales")
plt.plot(z,k,label="2024-sales")

plt.legend()
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/sample_data/business_data.csv")
df
# Out:
#    Month  Sales_2025  Sales_2026  Marketing_Spend  Customers
# 0    Jan       76422       72191            11949        760
# 1    Feb       35795       85788             7433        674
# 2    Mar       20860       69131            10311        258
# 3    Apr       58158       85263            10051        710
# 4    May       74343       41023            11420        881
# 5    Jun       64732       66090             6184        675
# 6    Jul       31284       26685             9555        899
# 7    Aug       74886       89820             8385        982
# 8    Sep       26265       25769            17309        389
# 9    Oct       36850       84735            11396        886
# 10   Nov       57194       87955            18035        762
# 11   Dec       41962       89925            16096        766

# %%
df.columns
# Out:
# Index(['Month', 'Sales_2025', 'Sales_2026', 'Marketing_Spend', 'Customers'], dtype='object')

# %%
x= df["Sales_2025"], df["Sales_2026"]
y=df["Month"], df["Month"]

# %%
plt.figure(figsize=(8,4))
plt.plot(y,x)
plt.title("Sales 2025 MOM")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-270/586350519.py in <cell line: 0>()
#       1 plt.figure(figsize=(8,4))
# ----> 2 plt.plot(y,x)
#       3 plt.title("Sales 2025 MOM")
#       4 plt.xlabel("Month")
#       5 plt.ylabel("Sales")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
# ...

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
#plt.grid(axis="y",colour='green')
plt.grid(color='green',linestyle='--',linewidth=0.5)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
x=np.array(["a","b","c","d"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
y=[20,10,40,30]
plt.pie(y)
plt.show()
