# %%
tasks=[]

while True:
  print("\n--- To Do List Application ---")
  print("1. Add Task")
  print("2. View Tasks")
  print("3. Mark Task as Done")
  print("4. Delete Task")
  print("5. Exit")

  choice = input("Enter your choice (1-5):")

  if choice == "1":
   task = input("Enter the task:")
   tasks.append((task,'Pending'))
   print("Task added successfully")

  # tasks = ["Study Python"]
  elif choice == "2":
    if len(tasks)==0:
     print("No tasks availaible.")
    else:
    # print("\nYour Tasks:")
     for i in range(len(tasks)):
      print(i+1,".",tasks[i][0,],"-",tasks[i][1])

  elif choice == "3":
      num= int(input('Enter task number: ')) -1
      if 0 <= num <len(tasks):
        tasks[num]=(tasks[num][0], 'Done')
        print('Task marked as done')
      else:
        print('Invalid task number.')

  elif choice =="4":
        num=int(input("Enter task number to delete:")) -1
        if 0 <= num <len(tasks):
          tasks.pop(num)
          print("Task deleted successfully.")
        else:
          print("Invalid task number.")

  elif choice == "5":
        print("Exiting To- Do App. Good bye !")
  break
# Out:
# --- To Do List Application ---
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Done
# 4. Delete Task
# 5. Exit
# Enter your choice (1-5):1
# Enter the task:10
# Task added successfully
