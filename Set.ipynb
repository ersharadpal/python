# %% [markdown]
# <a href="https://colab.research.google.com/github/ersharadpal/python/blob/main/Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set
s3=set()
print(type(s3))
print(s3)
# Out:
# <class 'set'>
# set()

# %%
list1=[1,2,3,5,6,7,7]

s4=set(list1)

print(s4)
print(type(s4))

# Set is constructer and remove duplicate
# Out:
# {1, 2, 3, 5, 6, 7}
# <class 'set'>

# %%
s3.add(3)
s3.add(4)
print(s3)
# Out:
# {3, 4}

# %%
s4.update([10,12,999])
print(s4)
# Out:
# {1, 2, 3, 5, 6, 7, 999, 10, 12}

# %%
s4.update((10,12,99))
print(s4)
# Out:
# {1, 2, 3, 99, 5, 6, 7, 999, 10, 12}

# %%
xourse="acciojob"
se=set(xourse)
print(se)
# Out:
# {'j', 'i', 'b', 'a', 'c', 'o'}

# %%
tup1=("aman","akash","aman","Akash")
print(tup1)

se_tup=set(tup1)
print(se_tup)
# Out:
# ('aman', 'akash', 'aman', 'Akash')
# {'aman', 'akash', 'Akash'}

# %%
print("before",se_tup)
se_tup.remove("aman")
print("after",se_tup)
# Out:
# before {'aman', 'akash', 'Akash'}
# after {'akash', 'Akash'}

# %%
print("before",se_tup)

se_tup.discard("aman")

print("after",se_tup)
# Out:
# before {'akash', 'Akash'}
# after {'akash', 'Akash'}

# %%
set1={"aman","akash","aman","Akash"}

for i in set1:
  print(i)
# Out:
# aman
# akash
# Akash

# %%
friends=["aman","jeetu","ram","shyam","krishan"]
c=set(friends)
c.remove("ram")
print(c)
# Out:
# {'krishan', 'aman', 'jeetu', 'shyam'}

# %%
a=set()
a.update(["aman","ram"])
print(a)
a.remove("ram")
print(a)
# Out:
# {'aman', 'ram'}
# {'aman'}

# %%
#Union operator
a={1,2,3}
b={3,4,5}

print(a|b)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Union operator
a={1,2,3}
b={3,4,5}
final=a.union(b)
print(final)

#print(a|b)
# Out:
# {1, 2, 3, 4, 5}

# %%
#intersaction

set1={1,3,3,3,4,5}
set2={1,2,3,4,5}
set1.intersection(set2)


#print(set1&set2)
# Out:
# {1, 3, 4, 5}

# %%
set1={1,3,3,3,4,5}
set2={1,2,3,4,5}
set1.difference(set2)


#
# Out:
# {1, 3, 4, 5}

# %%
course1={"english","hindi"}
course2={"english","sanskrit"}

c=course1.union(course2) # combine and unique
print(c)
d=course1.intersection(course2)
print(d)
e=course1.difference(course2)
print(e)
f=course1.symmetric_difference(course2)
print(f)
# Out:
# {'sanskrit', 'hindi', 'english'}
# {'english'}
# {'hindi'}
# {'sanskrit', 'hindi'}

# %%
data=[10,20,20,30,40,40]
c=set(data)
print(c)
# Out:
# {40, 10, 20, 30}

# %%
s={1,2,3,3,2}
print(s)
# Out:
# {1, 2, 3}

# %%
a=set()
a.add(1)
a.add(2)
a.add(3)
print(a)
# Out:
# {1, 2, 3}

# %%
s={}
s.add(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1459303180.py in <cell line: 0>()
#       1 s={}
# ----> 2 s.add(10)
#
# AttributeError: 'dict' object has no attribute 'add'

# %%
a={2,4,6,8}
b={4,8,12}
a.union(b)
# Out:
# {2, 4, 6, 8, 12}

# %%
a={10,20,30,40}
a.discard(30)
print(a)
# Out:
# {40, 10, 20}

# %%
5 in {5,10,15,20}
# Out:
# True

# %%
sentence ='python is easy and python is powerful'
a=set(sentence.split())
print(a)
# Out:
# {'python', 'is', 'powerful', 'and', 'easy'}

# %%
person={
    "name":"aman",
    "marks":21,
    "is_male":True
}
print(person)

print(type(person))
# Out:
# {'name': 'aman', 'marks': 21, 'is_male': True}
# <class 'dict'>

# %%
batch10={
    "name":["aman","akash","aditi","rahul"],
    "assignment":[23,24,25,27],
    "Is_male":[True,True,False,True],
    "gender":["Male","Male","Female","Male"]
}

print(batch10)
print(batch10["name"][-1])
#batch10.keys()
#batch10.items()
#batch10.values()
# Out:
# {'name': ['aman', 'akash', 'aditi', 'rahul'], 'assignment': [23, 24, 25, 27], 'Is_male': [True, True, False, True], 'gender': ['Male', 'Male', 'Female', 'Male']}
# rahul
# dict_items([('name', ['aman', 'akash', 'aditi', 'rahul']), ('assignment', [23, 24, 25, 27]), ('Is_male', [True, True, False, True]), ('gender', ['Male', 'Male', 'Female', 'Male'])])

# %%
for key,value in batch10.items():
 print(key,value)
# Out:
# name ['aman', 'akash', 'aditi', 'rahul']
# assignment [23, 24, 25, 27]
# Is_male [True, True, False, True]
# gender ['Male', 'Male', 'Female', 'Male']

# %%
s= {10, 20, 30}
s.add(20)
print(len(s))
# Out:
# 3

# %%
s={100,200,300}
c= list(s)
print(type(c))
print(c)
# Out:
# <class 'list'>
# [200, 100, 300]

# %%
s= set('hello')
print(s)
# Out:
# {'o', 'e', 'l', 'h'}

# %%
text='programming'
s= set(text)
print(s)
# Out:
# {'i', 'n', 'o', 'p', 'm', 'g', 'r', 'a'}

# %%
class_A = {'Aman','Riya','Karan','Neha'}
class_B = {'Neha','Simran','Aman'}
c= class_A.union (class_B)
print(c)
# Out:
# {'Simran', 'Aman', 'Riya', 'Karan', 'Neha'}
