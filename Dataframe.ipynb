# %% [markdown]
# <a href="https://colab.research.google.com/github/ersharadpal/python/blob/main/Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as xyz

# %%
import pandas as xyz
list1= ["akash","aman","sharad"]

xyz.DataFrame(list1,columns =["Name"], index=["1st student","2nd Student","3rd student"])
# Out:
#                Name
# 1st student   akash
# 2nd Student    aman
# 3rd student  sharad

# %%
Data_new = {
    "Name": ["sharry","Sonu","Monu","Nonu"],
    "Marks": [10,20,30,40]
}

# %%
import pandas as pd

pd.DataFrame(Data_new)
# Out:
#      Name  Marks
# 0  sharry     10
# 1    Sonu     20
# 2    Monu     30
# 3    Nonu     40

# %%
data = {
   "Name": ["sharry","Sonu","Monu","Nonu"],
    "Age": [10,20,30,40] ,
   "City" : ["Delhi","mumbai", "chennai","Hyderabad"]
}

# %%
#pd.DataFrame(data)
pd.Series(data)
# Out:
# Name             [sharry, Sonu, Monu, Nonu]
# Age                        [10, 20, 30, 40]
# City    [Delhi, mumbai, chennai, Hyderabad]
# dtype: object

# %%
list4= {
    ["Laptop", 5000,30],
    ["Mobile", 2000,40],
    ["tablet", 3000,50]
}

pd.DataFrame(list4, columns=["Product","Cost","Age"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1221532865.py in <cell line: 0>()
# ----> 1 list4= {
#       2     ["Laptop", 5000,30],
#       3     ["Mobile", 2000,40],
#       4     ["tablet", 3000,50]
#       5 }
#
# TypeError: unhashable type: 'list'
